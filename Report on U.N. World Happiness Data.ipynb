# %%
! pip install aimodelshare --upgrade
# Out:
# Collecting aimodelshare
#   Downloading aimodelshare-0.0.178-py3-none-any.whl (966 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 967.0/967.0 kB 16.9 MB/s eta 0:00:00a 0:00:01
# Collecting botocore==1.24.20
#   Downloading botocore-1.24.20-py3-none-any.whl (8.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 41.1 MB/s eta 0:00:0000:0100:01
# Collecting psutil>=5.9.1
#   Downloading psutil-5.9.4-cp36-abi3-macosx_10_9_x86_64.whl (243 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 243.5/243.5 kB 10.9 MB/s eta 0:00:00
# Collecting Pympler==0.9
#   Downloading Pympler-0.9.tar.gz (178 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.4/178.4 kB 8.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting onnxconverter-common>=1.7.0
#   Downloading onnxconverter_common-1.13.0-py2.py3-none-any.whl (83 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.8/83.8 kB 3.5 MB/s eta 0:00:00
# Collecting shortuuid>=1.0.8
#   Downloading shortuuid-1.0.11-py3-none-any.whl (10 kB)
# Collecting torch>=1.8.1
#   Downloading torch-1.13.1-cp39-none-macosx_10_9_x86_64.whl (135.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.3/135.3 MB 15.8 MB/s eta 0:00:0000:0100:01
# Collecting onnxmltools>=1.6.1
#   Downloading onnxmltools-1.11.1-py3-none-any.whl (308 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 308.6/308.6 kB 12.0 MB/s eta 0:00:00
# Requirement already satisfied: seaborn>=0.11.2 in ./opt/anaconda3/lib/python3.9/site-packages (from aimodelshare) (0.11.2)
# Collecting astunparse==1.6.3
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting pydot==1.3.0
#   Downloading pydot-1.3.0-py2.py3-none-any.whl (18 kB)
# Collecting skl2onnx>=1.8.0
#   Downloading skl2onnx-1.13-py2.py3-none-any.whl (288 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 288.7/288.7 kB 11.7 MB/s eta 0:00:00
# Collecting importlib-resources==5.10.0
#   Downloading importlib_resources-5.10.0-py3-none-any.whl (34 kB)
# Collecting onnx==1.12.0
#   Downloading onnx-1.12.0-cp39-cp39-macosx_10_12_x86_64.whl (12.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 49.0 MB/s eta 0:00:0000:0100:01
# Collecting PyJWT>=2.4.0
#   Downloading PyJWT-2.6.0-py3-none-any.whl (20 kB)
# Collecting pathlib>=1.0.1
#   Downloading pathlib-1.0.1-py3-none-any.whl (14 kB)
# Collecting onnxruntime>=1.7.0
#   Downloading onnxruntime-1.13.1-cp39-cp39-macosx_10_15_x86_64.whl (6.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 51.3 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: regex in ./opt/anaconda3/lib/python3.9/site-packages (from aimodelshare) (2022.3.15)
# Collecting tensorflow==2.9.2
#   Downloading tensorflow-2.9.2-cp39-cp39-macosx_10_14_x86_64.whl (228.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 228.6/228.6 MB 7.8 MB/s eta 0:00:0000:0100:01
# Collecting scikit-learn==0.24.2
#   Downloading scikit_learn-0.24.2-cp39-cp39-macosx_10_13_x86_64.whl (7.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.3/7.3 MB 47.4 MB/s eta 0:00:0000:0100:01
# Collecting boto3==1.21.20
#   Downloading boto3-1.21.20-py3-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.3/132.3 kB 1.3 MB/s eta 0:00:00a 0:00:01
# Collecting keras2onnx>=1.7.0
#   Downloading keras2onnx-1.7.0-py3-none-any.whl (96 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.3/96.3 kB 3.9 MB/s eta 0:00:00
# Collecting docker==5.0.0
#   Downloading docker-5.0.0-py2.py3-none-any.whl (146 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.0/147.0 kB 7.1 MB/s eta 0:00:00
# Collecting wget==3.2
#   Downloading wget-3.2.zip (10 kB)
#   Preparing metadata (setup.py) ... done
# Collecting tf2onnx
#   Downloading tf2onnx-1.13.0-py3-none-any.whl (442 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 442.3/442.3 kB 14.4 MB/s eta 0:00:00
# Requirement already satisfied: wheel<1.0,>=0.23.0 in ./opt/anaconda3/lib/python3.9/site-packages (from astunparse==1.6.3->aimodelshare) (0.37.1)
# Requirement already satisfied: six<2.0,>=1.6.1 in ./opt/anaconda3/lib/python3.9/site-packages (from astunparse==1.6.3->aimodelshare) (1.16.0)
# Requirement already satisfied: s3transfer<0.6.0,>=0.5.0 in ./opt/anaconda3/lib/python3.9/site-packages (from boto3==1.21.20->aimodelshare) (0.5.0)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in ./opt/anaconda3/lib/python3.9/site-packages (from boto3==1.21.20->aimodelshare) (0.10.0)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in ./opt/anaconda3/lib/python3.9/site-packages (from botocore==1.24.20->aimodelshare) (1.26.9)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in ./opt/anaconda3/lib/python3.9/site-packages (from botocore==1.24.20->aimodelshare) (2.8.2)
# Requirement already satisfied: websocket-client>=0.32.0 in ./opt/anaconda3/lib/python3.9/site-packages (from docker==5.0.0->aimodelshare) (0.58.0)
# Requirement already satisfied: requests!=2.18.0,>=2.14.2 in ./opt/anaconda3/lib/python3.9/site-packages (from docker==5.0.0->aimodelshare) (2.27.1)
# Requirement already satisfied: zipp>=3.1.0 in ./opt/anaconda3/lib/python3.9/site-packages (from importlib-resources==5.10.0->aimodelshare) (3.7.0)
# Requirement already satisfied: numpy>=1.16.6 in ./opt/anaconda3/lib/python3.9/site-packages (from onnx==1.12.0->aimodelshare) (1.21.5)
# Requirement already satisfied: protobuf<=3.20.1,>=3.12.2 in ./opt/anaconda3/lib/python3.9/site-packages (from onnx==1.12.0->aimodelshare) (3.19.1)
# Requirement already satisfied: typing-extensions>=3.6.2.1 in ./opt/anaconda3/lib/python3.9/site-packages (from onnx==1.12.0->aimodelshare) (4.1.1)
# Requirement already satisfied: pyparsing>=2.1.4 in ./opt/anaconda3/lib/python3.9/site-packages (from pydot==1.3.0->aimodelshare) (3.0.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in ./opt/anaconda3/lib/python3.9/site-packages (from scikit-learn==0.24.2->aimodelshare) (2.2.0)
# Requirement already satisfied: scipy>=0.19.1 in ./opt/anaconda3/lib/python3.9/site-packages (from scikit-learn==0.24.2->aimodelshare) (1.7.3)
# Requirement already satisfied: joblib>=0.11 in ./opt/anaconda3/lib/python3.9/site-packages (from scikit-learn==0.24.2->aimodelshare) (1.1.0)
# Collecting google-pasta>=0.1.1
#   Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 2.3 MB/s eta 0:00:00
# Collecting opt-einsum>=2.3.2
#   Downloading opt_einsum-3.3.0-py3-none-any.whl (65 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.5/65.5 kB 2.2 MB/s eta 0:00:00
# Collecting tensorflow-estimator<2.10.0,>=2.9.0rc0
#   Downloading tensorflow_estimator-2.9.0-py2.py3-none-any.whl (438 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 438.7/438.7 kB 13.4 MB/s eta 0:00:00
# Requirement already satisfied: setuptools in ./opt/anaconda3/lib/python3.9/site-packages (from tensorflow==2.9.2->aimodelshare) (61.2.0)
# Collecting keras<2.10.0,>=2.9.0rc0
#   Downloading keras-2.9.0-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 32.1 MB/s eta 0:00:0000:01
# Collecting libclang>=13.0.0
#   Downloading libclang-15.0.6.1-py2.py3-none-macosx_10_9_x86_64.whl (25.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.0/25.0 MB 36.2 MB/s eta 0:00:0000:0100:01
# Collecting absl-py>=1.0.0
#   Downloading absl_py-1.4.0-py3-none-any.whl (126 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.5/126.5 kB 5.7 MB/s eta 0:00:00
# Requirement already satisfied: wrapt>=1.11.0 in ./opt/anaconda3/lib/python3.9/site-packages (from tensorflow==2.9.2->aimodelshare) (1.12.1)
# Collecting termcolor>=1.1.0
#   Downloading termcolor-2.2.0-py3-none-any.whl (6.6 kB)
# Collecting tensorboard<2.10,>=2.9
#   Downloading tensorboard-2.9.1-py3-none-any.whl (5.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 63.1 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: h5py>=2.9.0 in ./opt/anaconda3/lib/python3.9/site-packages (from tensorflow==2.9.2->aimodelshare) (3.6.0)
# Collecting flatbuffers<2,>=1.12
#   Downloading flatbuffers-1.12-py2.py3-none-any.whl (15 kB)
# Collecting tensorflow-io-gcs-filesystem>=0.23.1
#   Downloading tensorflow_io_gcs_filesystem-0.30.0-cp39-cp39-macosx_10_14_x86_64.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 31.4 MB/s eta 0:00:0000:01
# Collecting keras-preprocessing>=1.1.1
#   Downloading Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 1.6 MB/s eta 0:00:00
# Requirement already satisfied: packaging in ./opt/anaconda3/lib/python3.9/site-packages (from tensorflow==2.9.2->aimodelshare) (21.3)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in ./opt/anaconda3/lib/python3.9/site-packages (from tensorflow==2.9.2->aimodelshare) (1.42.0)
# Collecting gast<=0.4.0,>=0.2.1
#   Downloading gast-0.4.0-py3-none-any.whl (9.8 kB)
# Collecting fire
#   Downloading fire-0.5.0.tar.gz (88 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.3/88.3 kB 3.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: sympy in ./opt/anaconda3/lib/python3.9/site-packages (from onnxruntime>=1.7.0->aimodelshare) (1.10.1)
# Collecting numpy>=1.16.6
#   Downloading numpy-1.24.2-cp39-cp39-macosx_10_9_x86_64.whl (19.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.8/19.8 MB 45.3 MB/s eta 0:00:0000:0100:01
# Collecting coloredlogs
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 1.7 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib>=2.2 in ./opt/anaconda3/lib/python3.9/site-packages (from seaborn>=0.11.2->aimodelshare) (3.5.1)
# Requirement already satisfied: pandas>=0.23 in ./opt/anaconda3/lib/python3.9/site-packages (from seaborn>=0.11.2->aimodelshare) (1.4.2)
# Requirement already satisfied: cycler>=0.10 in ./opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn>=0.11.2->aimodelshare) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in ./opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn>=0.11.2->aimodelshare) (1.3.2)
# Requirement already satisfied: fonttools>=4.22.0 in ./opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn>=0.11.2->aimodelshare) (4.25.0)
# Requirement already satisfied: pillow>=6.2.0 in ./opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn>=0.11.2->aimodelshare) (9.0.1)
# Requirement already satisfied: pytz>=2020.1 in ./opt/anaconda3/lib/python3.9/site-packages (from pandas>=0.23->seaborn>=0.11.2->aimodelshare) (2021.3)
# Requirement already satisfied: idna<4,>=2.5 in ./opt/anaconda3/lib/python3.9/site-packages (from requests!=2.18.0,>=2.14.2->docker==5.0.0->aimodelshare) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in ./opt/anaconda3/lib/python3.9/site-packages (from requests!=2.18.0,>=2.14.2->docker==5.0.0->aimodelshare) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in ./opt/anaconda3/lib/python3.9/site-packages (from requests!=2.18.0,>=2.14.2->docker==5.0.0->aimodelshare) (2.0.4)
# Collecting numpy>=1.16.6
#   Downloading numpy-1.22.4-cp39-cp39-macosx_10_15_x86_64.whl (17.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.7/17.7 MB 44.8 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: markdown>=2.6.8 in ./opt/anaconda3/lib/python3.9/site-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.2->aimodelshare) (3.3.4)
# Requirement already satisfied: google-auth<3,>=1.6.3 in ./opt/anaconda3/lib/python3.9/site-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.2->aimodelshare) (1.33.0)
# Collecting tensorboard-plugin-wit>=1.6.0
#   Downloading tensorboard_plugin_wit-1.8.1-py3-none-any.whl (781 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 781.3/781.3 kB 28.9 MB/s eta 0:00:00
# Collecting google-auth-oauthlib<0.5,>=0.4.1
#   Downloading google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: werkzeug>=1.0.1 in ./opt/anaconda3/lib/python3.9/site-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.2->aimodelshare) (2.0.3)
# Collecting tensorboard-data-server<0.7.0,>=0.6.0
#   Downloading tensorboard_data_server-0.6.1-py3-none-macosx_10_9_x86_64.whl (3.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 41.6 MB/s eta 0:00:0000:0100:01
# Collecting humanfriendly>=9.1
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 3.9 MB/s eta 0:00:00
# Requirement already satisfied: mpmath>=0.19 in ./opt/anaconda3/lib/python3.9/site-packages (from sympy->onnxruntime>=1.7.0->aimodelshare) (1.2.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in ./opt/anaconda3/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow==2.9.2->aimodelshare) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in ./opt/anaconda3/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow==2.9.2->aimodelshare) (4.2.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in ./opt/anaconda3/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow==2.9.2->aimodelshare) (4.7.2)
# Collecting requests-oauthlib>=0.7.0
#   Downloading requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in ./opt/anaconda3/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow==2.9.2->aimodelshare) (0.4.8)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.2.2-py3-none-any.whl (151 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 151.7/151.7 kB 6.2 MB/s eta 0:00:00
# Building wheels for collected packages: Pympler, wget, fire
#   Building wheel for Pympler (setup.py) ... done
#   Created wheel for Pympler: filename=Pympler-0.9-py3-none-any.whl size=164823 sha256=133e8a866705749c5f3fc22fb68382e6a4fe72f763136b6a3f6d384a95c8d8dd
#   Stored in directory: /Users/gua/Library/Caches/pip/wheels/0e/dc/d6/857ee17b3b11107746ba30ac38ceae0c8fa6defe025ee45182
#   Building wheel for wget (setup.py) ... done
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9675 sha256=4afa70227e056e38ccd09b57f7c98c9877590fde82c75f691dceac8d701c31fb
#   Stored in directory: /Users/gua/Library/Caches/pip/wheels/ba/78/fb/e0c24a9e73d7483b073d15b7e05f43f3fc2ac75eff6899c7aa
#   Building wheel for fire (setup.py) ... done
#   Created wheel for fire: filename=fire-0.5.0-py2.py3-none-any.whl size=116951 sha256=dc98eefb7a1f9b2327bb8dc13c13cdff27f1f93c8a57314d3dbae63777b449a0
#   Stored in directory: /Users/gua/Library/Caches/pip/wheels/34/a9/61/d515d3cd1e8a349fed305bc67a9c7d68fc38d51053b6decad6
# Successfully built Pympler wget fire
# Installing collected packages: wget, tensorboard-plugin-wit, Pympler, pathlib, libclang, keras, flatbuffers, torch, termcolor, tensorflow-io-gcs-filesystem, tensorflow-estimator, tensorboard-data-server, shortuuid, PyJWT, pydot, psutil, oauthlib, numpy, importlib-resources, humanfriendly, google-pasta, gast, astunparse, absl-py, requests-oauthlib, opt-einsum, onnx, keras-preprocessing, fire, docker, coloredlogs, botocore, tf2onnx, scikit-learn, onnxruntime, onnxconverter-common, google-auth-oauthlib, tensorboard, skl2onnx, keras2onnx, boto3, tensorflow, onnxmltools, aimodelshare
#   Attempting uninstall: PyJWT
#     Found existing installation: PyJWT 2.1.0
#     Uninstalling PyJWT-2.1.0:
#       Successfully uninstalled PyJWT-2.1.0
#   Attempting uninstall: psutil
#     Found existing installation: psutil 5.8.0
#     Uninstalling psutil-5.8.0:
#       Successfully uninstalled psutil-5.8.0
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.21.5
#     Uninstalling numpy-1.21.5:
#       Successfully uninstalled numpy-1.21.5
#   Attempting uninstall: botocore
#     Found existing installation: botocore 1.24.32
#     Uninstalling botocore-1.24.32:
#       Successfully uninstalled botocore-1.24.32
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.0.2
#     Uninstalling scikit-learn-1.0.2:
#       Successfully uninstalled scikit-learn-1.0.2
#   Attempting uninstall: boto3
#     Found existing installation: boto3 1.21.32
#     Uninstalling boto3-1.21.32:
#       Successfully uninstalled boto3-1.21.32
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# spyder 5.1.5 requires pyqt5<5.13, which is not installed.
# spyder 5.1.5 requires pyqtwebengine<5.13, which is not installed.
# daal4py 2021.5.0 requires daal==2021.4.0, which is not installed.
# numba 0.55.1 requires numpy<1.22,>=1.18, but you have numpy 1.22.4 which is incompatible.
# Successfully installed PyJWT-2.6.0 Pympler-0.9 absl-py-1.4.0 aimodelshare-0.0.178 astunparse-1.6.3 boto3-1.21.20 botocore-1.24.20 coloredlogs-15.0.1 docker-5.0.0 fire-0.5.0 flatbuffers-1.12 gast-0.4.0 google-auth-oauthlib-0.4.6 google-pasta-0.2.0 humanfriendly-10.0 importlib-resources-5.10.0 keras-2.9.0 keras-preprocessing-1.1.2 keras2onnx-1.7.0 libclang-15.0.6.1 numpy-1.22.4 oauthlib-3.2.2 onnx-1.12.0 onnxconverter-common-1.13.0 onnxmltools-1.11.1 onnxruntime-1.13.1 opt-einsum-3.3.0 pathlib-1.0.1 psutil-5.9.4 pydot-1.3.0 requests-oauthlib-1.3.1 scikit-learn-0.24.2 shortuuid-1.0.11 skl2onnx-1.13 tensorboard-2.9.1 tensorboard-data-server-0.6.1 tensorboard-plugin-wit-1.8.1 tensorflow-2.9.2 tensorflow-estimator-2.9.0 tensorflow-io-gcs-filesystem-0.30.0 termcolor-2.2.0 tf2onnx-1.13.0 torch-1.13.1 wget-3.2
#
# [notice] A new release of pip available: 22.3.1 -> 23.0
# [notice] To update, run: pip install --upgrade pip

# %%
from zipfile import ZipFile
with ZipFile("world_happiness_competition_data.zip") as zObject:
     zObject.extractall()

# %%
import pandas as pd
X_train = pd.read_csv('world_happiness_competition_data/X_train.csv')
X_test = pd.read_csv('world_happiness_competition_data/X_test.csv')
y_train = pd.read_csv('world_happiness_competition_data/y_train.csv')
y_train_labels = y_train.idxmax(axis=1)

X_train.head()
# Out:
#   Country or region  GDP per capita  Social support  Healthy life expectancy  \
# 0              Peru           0.960           1.274                    0.854
# 1         Nicaragua           0.694           1.325                    0.835
# 2            Greece           1.181           1.156                    0.999
# 3             Qatar           1.684           1.313                    0.871
# 4        Uzbekistan           0.745           1.529                    0.756
#
#    Freedom to make life choices  Generosity  Perceptions of corruption  \
# 0                         0.455       0.083                      0.027
# 1                         0.435       0.200                      0.127
# 2                         0.067       0.000                      0.034
# 3                         0.555       0.220                      0.167
# 4                         0.631       0.322                      0.240
#
#          name    region                       sub-region  Terrorist_attacks
# 0        Peru  Americas  Latin America and the Caribbean          18.000000
# 1   Nicaragua  Americas  Latin America and the Caribbean         125.611111
# 2      Greece    Europe                  Southern Europe         112.000000
# 3       Qatar      Asia                     Western Asia          57.333333
# 4  Uzbekistan      Asia                     Central Asia         125.611111

# %%
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer, make_column_transformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder

numeric_features = X_train.drop(['Country or region', 'name', 'region', 'sub-region'], axis=1)
numeric_features=numeric_features.columns.tolist()

numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())])

categorical_features = ['region', 'sub-region']

categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))])

preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_features),
        ('cat', categorical_transformer, categorical_features)])

preprocess=preprocessor.fit(X_train)

# %%
def preprocessor(data):
    data.drop(['Country or region', 'name'], axis=1)
    preprocessed_data=preprocess.transform(data)
    return preprocessed_data

# %%
preprocessor(X_train).shape
# Out:
# (88, 26)

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(n_estimators=300, max_depth=3)
model.fit(preprocessor(X_train), y_train_labels) # Fitting to the training set.
model.score(preprocessor(X_train), y_train_labels) # Fit score, 0-1 scale.
# Out:
# 0.8522727272727273

# %%
import aimodelshare as ai
ai.export_preprocessor(preprocessor,"")

# %%
from aimodelshare.aimsonnx import model_to_onnx

from skl2onnx.common.data_types import FloatTensorType

feature_count=preprocessor(X_test).shape[1]
initial_type = [('float_input', FloatTensorType([None, feature_count]))]

onnx_model = model_to_onnx(model, framework='sklearn',
                          initial_types=initial_type,
                          transfer_learning=False,
                          deep_learning=False)

with open("model.onnx", "wb") as f:
    f.write(onnx_model.SerializeToString())

# %%
from aimodelshare.aws import set_credentials

apiurl="https://e2w6gh3id1.execute-api.us-east-2.amazonaws.com/prod/m"

set_credentials(apiurl=apiurl)

# %%
import aimodelshare as ai
mycompetition= ai.Competition(apiurl)

# %%
prediction_labels = model.predict(preprocessor(X_test))

mycompetition.submit_model(model_filepath = "model.onnx",
                                 preprocessor_filepath="preprocessor.zip",
                                 prediction_submission=prediction_labels)

# %%
data = mycompetition.get_leaderboard()

mycompetition.stylize_leaderboard(data)
